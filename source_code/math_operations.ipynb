# %% [markdown]
# Class session

# %%
import math_operations as mathops

# %%
sum_all = mathops.basic_math.add(3,4,5,6,7,9)

# %%
print(mathops)
# Out:
# <module 'math_operations' from 'C:\\Users\\tatum\\OneDrive\\Desktop\\chee412\\feb4\\math_operations.py'>

# %%
print(sum_all)
# Out:
# 34

# %%
pro_all = mathops.basic_math.multiply(3,4,5,6,7,9)

# %%
print(pro_all)
# Out:
# 22680

# %%
x= list(range(0,15))
y= list(range(30,45))

# %%
mathops. plotting.plot_graph(x,y)
# Out:
# <Axes: title={'center': 'CHEE 412-005'}, xlabel='x axis', ylabel='y axis'>
